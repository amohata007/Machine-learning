# %%
import pandas as pd

# %%
dataset= pd.read_csv("data.csv")

# %%
dataset.head()
# Out:
#                 REQUIREMENT               TYPE BUDGET  TIME TECHNOLOGY
# 0       analytic operations   Batch Processing    low  more     Hadoop
# 1       analytic operations     streaming data   high  less      Spark
# 2       analytic operations      critical data   high  less      Spark
# 3       analytic operations  non-critical data    low  more     hadoop
# 4  analytic operations        Batch Processing   high  less      Spark

# %%
y = dataset.iloc[:,-1]

# %%
X = dataset.iloc[:,0:6]

# %%
y
# Out:
# 0               Hadoop
# 1                Spark
# 2                Spark
# 3               hadoop
# 4                Spark
# 5              Ansible
# 6         public cloud
# 7        private cloud
# 8           containers
# 9          hypervisors
# 10       SQL databases
# 11       SQL databases
# 12       SQL databases
# 13       SQL databases
# 14    No SQL databases
# 15    No SQL databases
# 16    No SQL databases
# 17    No SQL databases
# 18              Puppet
# 19             Ansible
# 20              Puppet
# Name: TECHNOLOGY, dtype: object

# %%
X
# Out:
#                  REQUIREMENT                         TYPE BUDGET  TIME  \
# 0        analytic operations             Batch Processing    low  more
# 1        analytic operations               streaming data   high  less
# 2        analytic operations                critical data   high  less
# 3        analytic operations            non-critical data    low  more
# 4   analytic operations                  Batch Processing   high  less
# 5                     devops                  intelligent   high  less
# 6                    storage                critical data    low  more
# 7                    storage                critical data   high  more
# 8             virtualization                   scalablity   less  less
# 9             virtualization                data security   less  more
# 10                 databases              rigid structure   high  more
# 11                 databases              rigid structure    low  less
# 12                 databases              rigid structure   high  less
# 13                 databases              rigid structure    low  more
# 14                 databases           flexible structure   high  more
# 15                 databases           flexible structure    low  less
# 16                 databases           flexible structure   high  less
# 17                 databases           flexible structure    low  more
# 18                    devops  installation and deployment    low  more
# 19                    devops  installation and deployment   high  less
# 20                    devops                 installation    low  less
#
#           TECHNOLOGY
# 0             Hadoop
# 1              Spark
# 2              Spark
# 3             hadoop
# 4              Spark
# 5            Ansible
# 6       public cloud
# 7      private cloud
# 8         containers
# 9        hypervisors
# 10     SQL databases
# 11     SQL databases
# 12     SQL databases
# 13     SQL databases
# 14  No SQL databases
# 15  No SQL databases
# 16  No SQL databases
# 17  No SQL databases
# 18            Puppet
# 19           Ansible
# 20            Puppet

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=42)

# %%
X_train
# Out:
#                  REQUIREMENT                         TYPE BUDGET  TIME  \
# 3        analytic operations            non-critical data    low  more
# 18                    devops  installation and deployment    low  more
# 16                 databases           flexible structure   high  less
# 13                 databases              rigid structure    low  more
# 2        analytic operations                critical data   high  less
# 9             virtualization                data security   less  more
# 20                    devops                 installation    low  less
# 4   analytic operations                  Batch Processing   high  less
# 12                 databases              rigid structure   high  less
# 7                    storage                critical data   high  more
# 10                 databases              rigid structure   high  more
# 14                 databases           flexible structure   high  more
# 19                    devops  installation and deployment   high  less
# 6                    storage                critical data    low  more
#
#           TECHNOLOGY
# 3             hadoop
# 18            Puppet
# 16  No SQL databases
# 13     SQL databases
# 2              Spark
# 9        hypervisors
# 20            Puppet
# 4              Spark
# 12     SQL databases
# 7      private cloud
# 10     SQL databases
# 14  No SQL databases
# 19           Ansible
# 6       public cloud

# %%
X_train.shape
# Out:
# (14, 5)

# %%
#model = LinearRegression()

# %%
#model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#y_pred = model.predict(X_test)

# %%
y_test
# Out:
# 0               Hadoop
# 17    No SQL databases
# 15    No SQL databases
# 1                Spark
# 8           containers
# 5              Ansible
# 11       SQL databases
# Name: TECHNOLOGY, dtype: object
