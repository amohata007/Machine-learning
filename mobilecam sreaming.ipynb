# %%
url = "http://192.168.43.1:8080/shot.jpg"

# %%
#whenever we access http we need to use requests
import requests
import cv2
import numpy

# %%
while True:
    
    data = requests.get(url)
    img_content = data.content
    img_contentarray = bytearray(img_content)
    img_1d = numpy.array(img_contentarray)
    img = cv2.imdecode(img_1d, -1)
    cv2.imshow('pic',img)
    if cv2.waitKey(1)==13:
        break
cv2.DestroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-b4069c519951> in <module>()
#       5     img_contentarray = bytearray(img_content)
#       6     img_1d = numpy.array(img_contentarray)
# ----> 7     img = cv2.imdecode(img_1d, -1)
#       8     cv2.imshow('pic',img)
#       9     if cv2.waitKey(1)==13:
#
# error: OpenCV(3.4.5) C:\projects\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:751: error: (-215:Assertion failed) !buf.empty() && buf.isContinuous() in function 'cv::imdecode_'

# %%
data

# %%
img_content
#image is in byte data type

# %%
numpy.array(img_content)
